# %% [markdown]
# <a href="https://colab.research.google.com/github/Karazakoff/Data_Analysis/blob/main/Jupyter_NoteBook_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
x = 10

# %%
x
# Out:
# 10
